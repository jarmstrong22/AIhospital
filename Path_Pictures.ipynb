# %% [markdown]
# <a href="https://colab.research.google.com/github/jarmstrong22/AIhospital/blob/main/Path_Pictures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Path (1)**
#
# *   Delivery algorithm: A*
# *   Start location: 0,21
# *   Delivery locations: Medical Ward, ICU, ER, Oncology
#
# This is the **first** of two variations of the same path, this one **without an obstacle**

# %% [markdown]
# ![path1.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# # Path (2)
# *   Delivery algorithm: A*
# *   Start location: 0,21
# *   Delivery locations: Medical Ward, ICU, ER, Oncology
# *   Obstacle: 21,14
#
# This is the **second** of two variations of the same path, this one **with an obstacle**

# %% [markdown]
# ![Path2.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# # **Path(3)**
#
#
# *   Delivery algorithm: Dijkstra
# *   Start location: 12,13
# *   Delivery locations: General Ward, Admissions, Pediatric Ward
#
# This is the **first** of two variations of the same path using **dijkstra**, this one **without an obstacle**

# %% [markdown]
# ![Path3.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# # Path (4)
# *   Delivery algorithm: Dijkstra
# *   Start location: 12,13
# *   Delivery locations: General Ward, Admissions, Pediatric Ward
# *   Obstacle: 15,2
#
# This is the **second** of two variations of the same path using **dijkstra**, this one **with an obstacle**

# %% [markdown]
# ![Path4.png](data:image/png;base64,...)

# %% [markdown]
# # **Path(5)**
#
#
# *   Delivery algorithm: A*
# *   Start location: 2,3
# *   Delivery locations: Admissions, Isolation Ward, Hematology, Burn Ward
#
# This is the **first** of two variations of the same path but using A* or Dijkstra, this one is **A***

# %% [markdown]
# ![Path5.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# # **Path(6)**
#
#
# *   Delivery algorithm: Dijkstra
# *   Start location: 2,3
# *   Delivery locations: Admissions, Isolation Ward, Hematology, Burn Ward
#
# This is the **first** of two variations of the same path but using A* or Dijkstra, this one is **Dijkstra**

# %% [markdown]
# ![Path6.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# # **Path(7)**
#
#
# *   Delivery algorithm: A*
# *   Start location: 2,3
# *   Delivery locations: Maternity Ward, Surgical Wa
#
# This is meant to show the error handling process for an incorrect ward input

# %% [markdown]
# ![Path7.png](data:image/png;base64,...)

# %% [markdown]
# ![Output.png](data:image/png;base64,...)
